# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
import glob

import psycopg2 as pg2
import psycopg2.extras

from dotenv import load_dotenv
import os

# %%
load_dotenv()
DB_NAME = os.getenv('DB_NAME')
DB_USER = os.getenv('DB_USER')
DB_PASSWORD = os.getenv('DB_PASSWORD')
DB_HOST = os.getenv('DB_HOST')

# %%
conn = pg2.connect(database=DB_NAME,  
                        user=DB_USER, 
                        password=DB_PASSWORD,  
                        host=DB_HOST, 
                        port="5432", 
                        cursor_factory = psycopg2.extras.RealDictCursor)
cur = conn.cursor()

# %%
cur.execute('''select *
            from area_codes''')

# %%
rand_dict = {'one': 1, "two": 2, "three":3}
rand_dict.keys()
# Out:
# dict_keys(['one', 'two', 'three'])

# %%
body_elements = {'event':None, 'name':None, 'email':None, 'dob':None, 'phone':None}
for element in body_elements:
    if element is None:
        return {"message": f'{element} is required'}, 400
    else:
        body_elements[element] = body.get('element')

# %%
for thangs in cur:
    print(thangs)
# Out:
# RealDictRow({'area_code': 201, 'city': 'Bergenfield', 'state': 'New Jersey', 'country': 'US', 'latitude': 40.9276, 'longitude': -73.99736})
# RealDictRow({'area_code': 201, 'city': 'Cliffside Park', 'state': 'New Jersey', 'country': 'US', 'latitude': 40.82149, 'longitude': -73.98764})
# RealDictRow({'area_code': 201, 'city': 'Englewood', 'state': 'New Jersey', 'country': 'US', 'latitude': 40.89288, 'longitude': -73.97264})
# RealDictRow({'area_code': 201, 'city': 'Fair Lawn', 'state': 'New Jersey', 'country': 'US', 'latitude': 40.94038, 'longitude': -74.13181})
# RealDictRow({'area_code': 201, 'city': 'Fort Lee', 'state': 'New Jersey', 'country': 'US', 'latitude': 40.85093, 'longitude': -73.97014})
# RealDictRow({'area_code': 201, 'city': 'Hackensack', 'state': 'New Jersey', 'country': 'US', 'latitude': 40.88593, 'longitude': -74.04347})
# RealDictRow({'area_code': 201, 'city': 'Hoboken', 'state': 'New Jersey', 'country': 'US', 'latitude': 40.74399, 'longitude': -74.03236})
# ...

# %%
cur.close() 
conn.close()
